# %%
import pandas as pd

# %%
deliv_df=pd.read_csv("deliveries.csv")

# %%
df=deliv_df.query("batsman_runs=='6'")

# %%
df
# Out:
#         match_id  inning                 batting_team  \
# 10             1       1          Sunrisers Hyderabad
# 47             1       1          Sunrisers Hyderabad
# 75             1       1          Sunrisers Hyderabad
# 89             1       1          Sunrisers Hyderabad
# 91             1       1          Sunrisers Hyderabad
# 105            1       1          Sunrisers Hyderabad
# 115            1       1          Sunrisers Hyderabad
# 121            1       1          Sunrisers Hyderabad
# 124            1       1          Sunrisers Hyderabad
# 142            1       2  Royal Challengers Bangalore
# 144            1       2  Royal Challengers Bangalore
# 164            1       2  Royal Challengers Bangalore
# 180            1       2  Royal Challengers Bangalore
# 219            1       2  Royal Challengers Bangalore
# 221            1       2  Royal Challengers Bangalore
# 241            1       2  Royal Challengers Bangalore
# ...

# %%
bowler=df.groupby('bowler')

# %%
bowler.aggregate('count')
# Out:
#                    match_id  inning  batting_team  bowling_team  over  ball  \
# bowler
# A Ashish Reddy           20      20            20            20    20    20
# A Chandila               10      10            10            10    10    10
# A Choudhary               6       6             6             6     6     6
# A Dananjaya               4       4             4             4     4     4
# A Flintoff                7       7             7             7     7     7
# A Joseph                  5       5             5             5     5     5
# A Kumble                 35      35            35            35    35    35
# A Mishra                170     170           170           170   170   170
# A Mithun                 21      21            21            21    21    21
# A Nehra                  76      76            76            76    76    76
# A Nel                     2       2             2             2     2     2
# ...

# %%
print("A Mishra has been hit for maximum number of sixes")
# Out:
# A Mishra has been hit for maximum number of sixes

# %%
deliv_df=pd.read_csv("deliveries.csv")

# %%
df=deliv_df.query("batsman_runs=='4'")

# %%
df
# Out:
#         match_id  inning                 batting_team  \
# 2              1       1          Sunrisers Hyderabad
# 8              1       1          Sunrisers Hyderabad
# 13             1       1          Sunrisers Hyderabad
# 30             1       1          Sunrisers Hyderabad
# 32             1       1          Sunrisers Hyderabad
# 33             1       1          Sunrisers Hyderabad
# 35             1       1          Sunrisers Hyderabad
# 36             1       1          Sunrisers Hyderabad
# 63             1       1          Sunrisers Hyderabad
# 72             1       1          Sunrisers Hyderabad
# 74             1       1          Sunrisers Hyderabad
# 76             1       1          Sunrisers Hyderabad
# 81             1       1          Sunrisers Hyderabad
# 87             1       1          Sunrisers Hyderabad
# 101            1       1          Sunrisers Hyderabad
# 109            1       1          Sunrisers Hyderabad
# ...

# %%
bowler=df.groupby('bowler')

# %%
bowler.aggregate('count')
# Out:
#                    match_id  inning  batting_team  bowling_team  over  ball  \
# bowler
# A Ashish Reddy           26      26            26            26    26    26
# A Chandila               17      17            17            17    17    17
# A Choudhary              13      13            13            13    13    13
# A Dananjaya               2       2             2             2     2     2
# A Flintoff                7       7             7             7     7     7
# A Joseph                 10      10            10            10    10    10
# A Kumble                 72      72            72            72    72    72
# A Mishra                218     218           218           218   218   218
# A Mithun                 42      42            42            42    42    42
# A Nehra                 279     279           279           279   279   279
# A Nel                     3       3             3             3     3     3
# ...

# %%
print("UT Yadav was hit for maximum number of 4's")
# Out:
# UT Yadav was hit for maximum number of 4's

# %%
df=deliv_df.query("batsman_runs=='2'")

# %%
df
# Out:
#         match_id  inning                 batting_team  \
# 29             1       1          Sunrisers Hyderabad
# 50             1       1          Sunrisers Hyderabad
# 54             1       1          Sunrisers Hyderabad
# 55             1       1          Sunrisers Hyderabad
# 66             1       1          Sunrisers Hyderabad
# 67             1       1          Sunrisers Hyderabad
# 79             1       1          Sunrisers Hyderabad
# 111            1       1          Sunrisers Hyderabad
# 122            1       1          Sunrisers Hyderabad
# 128            1       2  Royal Challengers Bangalore
# 145            1       2  Royal Challengers Bangalore
# 161            1       2  Royal Challengers Bangalore
# 170            1       2  Royal Challengers Bangalore
# 197            1       2  Royal Challengers Bangalore
# 203            1       2  Royal Challengers Bangalore
# 232            1       2  Royal Challengers Bangalore
# ...

# %%
bowler=df.groupby('bowler')

# %%
bowler.aggregate('count')
# Out:
#                    match_id  inning  batting_team  bowling_team  over  ball  \
# bowler
# A Ashish Reddy           23      23            23            23    23    23
# A Chandila               10      10            10            10    10    10
# A Choudhary               9       9             9             9     9     9
# A Dananjaya               2       2             2             2     2     2
# A Flintoff                4       4             4             4     4     4
# A Joseph                  2       2             2             2     2     2
# A Kumble                 57      57            57            57    57    57
# A Mishra                232     232           232           232   232   232
# A Mithun                 17      17            17            17    17    17
# A Nehra                 103     103           103           103   103   103
# A Nel                     1       1             1             1     1     1
# ...

# %%
print("A Mishra was hit for maximum number of 2's")
# Out:
# A Mishra was hit for maximum number of 2's

# %%
df=deliv_df.query("batsman_runs==1")

# %%
bowler=df.groupby('bowler')

# %%
bowler.aggregate('count')
# Out:
#                    match_id  inning  batting_team  bowling_team  over  ball  \
# bowler
# A Ashish Reddy          110     110           110           110   110   110
# A Chandila               91      91            91            91    91    91
# A Choudhary              31      31            31            31    31    31
# A Dananjaya              11      11            11            11    11    11
# A Flintoff               27      27            27            27    27    27
# A Joseph                 15      15            15            15    15    15
# A Kumble                406     406           406           406   406   406
# A Mishra               1353    1353          1353          1353  1353  1353
# A Mithun                117     117           117           117   117   117
# A Nehra                 621     621           621           621   621   621
# A Nel                     5       5             5             5     5     5
# ...

# %%
print("A Mishra was hit for maximum number of 1's")
# Out:
# A Mishra was hit for maximum number of 1's
