# %%
import pandas as pd

# %%
deliv_df=pd.read_csv("deliveries.csv")

# %%
deliv_df
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 5              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 6              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 7              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 8              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 9              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 10             1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...

# %%
df=deliv_df.query("player_dismissed==non_striker&dismissal_kind=='run out'")

# %%
df
# Out:
#         match_id  inning                 batting_team  \
# 247            1       2  Royal Challengers Bangalore
# 371            2       1               Mumbai Indians
# 2700          12       1  Royal Challengers Bangalore
# 4989          21       2             Delhi Daredevils
# 5399          23       1        Kolkata Knight Riders
# 5546          24       1               Mumbai Indians
# 5632          24       1               Mumbai Indians
# 5966          25       2       Rising Pune Supergiant
# 6680          28       2               Mumbai Indians
# 6823          29       2        Kolkata Knight Riders
# 6980          30       1  Royal Challengers Bangalore
# 7328          31       2        Kolkata Knight Riders
# 7963          34       1                Gujarat Lions
# 7994          34       2               Mumbai Indians
# 8091          34       2               Mumbai Indians
# 8386          36       1          Sunrisers Hyderabad
# ...

# %%
nstriker=df.groupby('non_striker')

# %%
nstriker.aggregate('count')
# Out:
#                    match_id  inning  batting_team  bowling_team  over  ball  \
# non_striker
# A Chopra                  1       1             1             1     1     1
# A Kumble                  1       1             1             1     1     1
# A Mishra                  4       4             4             4     4     4
# A Nehra                   1       1             1             1     1     1
# A Nel                     1       1             1             1     1     1
# A Symonds                 3       3             3             3     3     3
# AA Chavan                 1       1             1             1     1     1
# AA Jhunjhunwala           1       1             1             1     1     1
# AB Agarkar                2       2             2             2     2     2
# AB Dinda                  1       1             1             1     1     1
# AB de Villiers            8       8             8             8     8     8
# ...

# %%
print("AT rayudu was the non-striker part of in maximum number of run outs")
# Out:
# AT rayudu was the non-striker part of in maximum number of run outs
