# %%
import pandas as pd

# %%
import math

# %%
deliv_csv=pd.read_csv("deliveries.csv")

# %%
df2=deliv_csv.query("total_runs=='0'")

# %%
df2
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 5              1       1          Sunrisers Hyderabad
# 11             1       1          Sunrisers Hyderabad
# 12             1       1          Sunrisers Hyderabad
# 15             1       1          Sunrisers Hyderabad
# 16             1       1          Sunrisers Hyderabad
# 20             1       1          Sunrisers Hyderabad
# 22             1       1          Sunrisers Hyderabad
# 31             1       1          Sunrisers Hyderabad
# 34             1       1          Sunrisers Hyderabad
# 39             1       1          Sunrisers Hyderabad
# 56             1       1          Sunrisers Hyderabad
# 61             1       1          Sunrisers Hyderabad
# 64             1       1          Sunrisers Hyderabad
# ...

# %%
df2=df2.query("dismissal_kind!='caught'&dismissal_kind!='bowled'&dismissal_kind!='stumped'&dismissal_kind!='run out'&dismissal_kind!='lbw'")

# %%
df2
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 5              1       1          Sunrisers Hyderabad
# 12             1       1          Sunrisers Hyderabad
# 15             1       1          Sunrisers Hyderabad
# 16             1       1          Sunrisers Hyderabad
# 20             1       1          Sunrisers Hyderabad
# 22             1       1          Sunrisers Hyderabad
# 31             1       1          Sunrisers Hyderabad
# 34             1       1          Sunrisers Hyderabad
# 39             1       1          Sunrisers Hyderabad
# 56             1       1          Sunrisers Hyderabad
# 61             1       1          Sunrisers Hyderabad
# 69             1       1          Sunrisers Hyderabad
# 77             1       1          Sunrisers Hyderabad
# ...

# %%
batsmen=df2.groupby("batsman")

# %%
batsmen.aggregate('count')
# Out:
#                       match_id  inning  batting_team  bowling_team  over  \
# batsman
# A Ashish Reddy              42      42            42            42    42
# A Chandila                   2       2             2             2     2
# A Chopra                    35      35            35            35    35
# A Choudhary                  2       2             2             2     2
# A Dananjaya                  2       2             2             2     2
# A Flintoff                  16      16            16            16    16
# A Hales                     40      40            40            40    40
# A Joseph                     6       6             6             6     6
# A Kumble                    18      18            18            18    18
# A Mishra                   126     126           126           126   126
# A Mithun                     4       4             4             4     4
# A Mukund                     6       6             6             6     6
# ...

# %%
print("Player that faced most no. of dot balls is Virat Kohli")
# Out:
# Player that faced most no. of dot balls is Virat Kohli
