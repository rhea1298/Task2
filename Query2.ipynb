# %%
import pandas as pd

# %%
matches_df=pd.read_csv('matches.csv')

# %%
matches_df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
df=matches_df[matches_df['toss_winner']==matches_df['winner']]

# %%
df1=df.query("toss_decision=='field'")

# %%
df2=df.query("toss_decision=='bat'")

# %%
venue1=df1.groupby("venue")

# %%
venue2=df2.groupby("venue")

# %%
venue1.aggregate("count")
# Out:
#                                                     id  season  city  date  \
# venue
# ACA-VDCA Stadium                                     2       2     2     2
# Barabati Stadium                                     3       3     3     3
# Brabourne Stadium                                    3       3     3     3
# De Beers Diamond Oval                                1       1     1     1
# Dr DY Patil Sports Academy                           6       6     6     6
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Sta...   2       2     2     2
# Dubai International Cricket Stadium                  2       2     0     2
# Eden Gardens                                        31      31    31    31
# Feroz Shah Kotla                                    20      20    20    20
# Feroz Shah Kotla Ground                              3       3     3     3
# Green Park                                           4       4     4     4
# ...

# %%
venue2.aggregate("count")
# Out:
#                                                     id  season  city  date  \
# venue
# Barabati Stadium                                     2       2     2     2
# Brabourne Stadium                                    4       4     4     4
# Buffalo Park                                         2       2     2     2
# De Beers Diamond Oval                                1       1     1     1
# Dr DY Patil Sports Academy                           3       3     3     3
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Sta...   2       2     2     2
# Dubai International Cricket Stadium                  1       1     0     1
# Eden Gardens                                        12      12    12    12
# Feroz Shah Kotla                                    13      13    13    13
# Feroz Shah Kotla Ground                              2       2     2     2
# Himachal Pradesh Cricket Association Stadium         1       1     1     1
# ...

# %%
print("At Eden Garden's field is the favourable toss decision")
# Out:
# At Eden Garden's field is the favourable toss decision

# %%
print("At Feroz Shah Kotla field is the favourable toss decision")
# Out:
# At Feroz Shah Kotla field is the favourable toss decision

# %%
print("At Wankhede stadium field is the favourable toss decision")
# Out:
# At Wankhede stadium field is the favourable toss decision

# %%
print("At Sheikh Zayed stadium bat is the favourable toss decision")
